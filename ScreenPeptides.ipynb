# %%
# %%writefile ScreenPeptides.py

from pyrosetta import *
from pyrosetta.rosetta.protocols.flexpep_docking import FlexPepDockingProtocol
from pyrosetta import PyMOLMover
from pyrosetta.rosetta import *
from pyrosetta.toolbox.py_jobdistributor import output_scorefile

def fp_dock_init():
    """
    Use to init parameters for the flexpep run. The ones below are currently working reasonably. 
    Best guide to the params that I have found is here:
    
    https://new.rosettacommons.org/docs/latest/application_documentation/docking/flex-pep-dock
    
    """
    opts = "-pep_refine -ex1 -ex2aro -use_input_sc -ignore_unrecognized_res"
    init(opts)

# copied from D090_Ala_scan.py in the example scripts for PyRosetta
def calc_binding_energy(pose, scorefxn, center, cutoff = 8.0):
    scorefxn = create_score_function(scorefxn)
    
    # create a copy of the pose for manipulation
    test_pose = Pose()
    test_pose.assign(pose)

    # setup packer options
    # the sidechain conformations of residues "near the interface", defined as
    #    within  <cutoff>  Angstroms of an interface residue, may change and
    #    must be repacked, if all residues are repacked, aberrant sidechain
    #    conformations near the interface, but independent of complex
    #    interactions, will be repacked for the mutant and wild-type structures
    #    preventing them from adding noise to the score difference
    # this method of setting up a PackerTask is different from packer_task.py
    tf = standard_task_factory()    # create a TaskFactory
    tf.push_back(core.pack.task.operation.RestrictToRepacking())    # restrict it to repacking

    # this object contains repacking options, instead of turning the residues
    #    "On" or "Off" directly, this will create an object for these options
    #    and assign it to the TaskFactory
    prevent_repacking = core.pack.task.operation.PreventRepacking()

    # the "center" (nbr_atom) of the mutant residue, for distance calculation
    center = test_pose.residue(center).nbr_atom_xyz()
    for i in range(1, test_pose.total_residue() + 1):
        # the .distance_squared method is (a little) lighter than .norm
        # if the residue is further than <cutoff> Angstroms away, do not repack
        if center.distance_squared(
                test_pose.residue(i).nbr_atom_xyz()) > cutoff**2:
            prevent_repacking.include_residue(i)

    # apply these settings to the TaskFactory
    tf.push_back(prevent_repacking)

    # setup a PackRotamersMover
    # changed by colin
    packer = protocols.minimization_packing.PackRotamersMover(scorefxn)
    packer.task_factory(tf)

    #### create a Mover for performing translation
    #### RigidBodyTransMover is SUPPOSED to translate docking partners of a
    ####    pose based on an axis and magnitude
    #### test it using the PyMOLMover, it does not perform a simple translation
    ####    I also observed a "Hbond Tripped" error when packing after applying
    ####    the Mover, it appears to store inf and NaN values into hbonds
    #transmover = RigidBodyTransMover()
    # calc_interaction_energy separates the chains by 500.0 Angstroms,
    #    so does this Mover
    # if using this Mover, the step_size MUST be a float
    # if this setting is left to default, it will move the proteins
    #    VERY far apart
    #transmover.step_size( 5.0 )

    # repack the test_pose
    packer.apply(test_pose)

    # score this structure
    before = scorefxn(test_pose)

    # separate the docking partners
    #### since RigidBodyTransMover DOES NOT WORK, it is not used
    #transmover.apply(test_pose)

    # here are two methods for applying a translation onto a pose structure
    # both require an xyzVector
    xyz = rosetta.numeric.xyzVector_double_t()    # a Vector for coordinates
    xyz.x = 500.0    # arbitrary separation magnitude, in the x direction
    xyz.y = 0.0    #...I didn't have this and it defaulted to 1e251...?
    xyz.z = 0.0    #...btw thats like 1e225 light years,
                   #    over 5e245 yrs at Warp Factor 9.999 (thanks M. Pacella)

    #### here is a hacky method for translating the downstream partner of a
    #    pose protein-protein complex (must by two-body!)
    chain2starts = len(pose.chain_sequence(1)) + 1
    for r in range(chain2starts, test_pose.total_residue() + 1):
        for a in range(1, test_pose.residue(r).natoms() + 1):
            test_pose.residue(r).set_xyz(a,
                test_pose.residue(r).xyz(a) + xyz)

    # here is an elegant way to do it, it assumes that jump number 1
    #    defines the docking partners "connectivity"
    # the pose.jump method returns a jump object CREATED from the pose jump
    #    data, the pose itself does not own a Jump object, thus you can use
    #    Jump methods, such as pose.jump(1).set_translation, however the object
    #    has not been properly constructed for manipulation, thus performing
    #    a change does not cause any problems, but is not permanently applied
    #translate = test_pose.jump( 1 )    # copy this information explicitly
    # adjust its translation via vector addition
    #translate.set_translation( translate.get_translation() + xyz )
    #test_pose.set_jump( 1 , translate )
    # as explained above, this call will NOT work
    #test_pose.jump(1).set_translation( test_pose.get_translation() + xyz )

    # repack the test_pose after separation
    packer.apply(test_pose)

    # return the change in score
    return before - scorefxn(test_pose)

# Also copied from D090_Ala_scan.py in the example scripts for PyRosetta
def ddG(wt_pose, mut_pose, mutant_position, sf='docking', repack_distance=8, replicate_runs=20):
    a = []
    
    for _ in range(replicate_runs):
        wt_score = calc_binding_energy(wt_pose, sf,
            mutant_position, repack_distance)
        mut_score = calc_binding_energy(mut_pose, sf,
            mutant_position, repack_distance)
        #### the method calc_interaction_energy separates an input pose by
        ####    500 Angstroms along the jump defined in a Vector1 of jump numbers
        ####    for movable jumps, a ScoreFunction must also be provided
        #### if setup_foldtree has not been applied, calc_interaction_energy may be
        ####    wrong (since the jumps may be wrong)
        #wt_score = calc_interaction_energy(wt, scorefxn, movable_jumps)
        #mut_score = calc_interaction_energy(mutant, scorefxn, movable_jumps)
        ddg = mut_score - wt_score
        a.append(ddg)
    
    return np.mean(a)

def pep_run(decoy_name, n_decoys, pose, sf='docking', pymol_ip_addr=None):
    """
    Tested score function is 'docking' not sure if this is the best. Is there a way to run this in a 
    distributed fashion? Each decoy takes ~3 minutes on my machine.
    """
    if pymol_ip_addr:
        pmm = PyMOLMover(pymol_ip_addr, 65000) #enter the IP that pymol displays on startup
        pmm.keep_history(True)
    
    # Score function and starting PDB
    sf = create_score_function(sf) # no idea what this sf is...
    #pose = pose_from_pdb(pdb)

    # Creating FlexPepDock protocol using init options
    fpdock = FlexPepDockingProtocol()

    jd = PyJobDistributor(decoy_name, n_decoys, sf)
    while not jd.job_complete:
        pp = Pose()
        pp.assign(pose)
        fpdock.apply(pp)
        if pymol_ip_addr:
            pmm.apply(pp)
        jd.output_decoy(pp) # this will output a PDB file, which is not really necessary.

def pep_multicore_run(input_path, destination_path, filenames, nstructs):
    """
    Spreads a run onto as many cores as filenames. Good for looking at many peptides/mutants at once.
    This might need to get changed to input poses at some point?
    """
    import time
    from multiprocessing import Pool
    
    timestr = time.strftime("%Y%m%d-%H%M%S")

    with Pool() as p:
        work = [(destination_path+filename[:-4]+"-"+timestr+"_"+str(n), nstructs, None, None, pose_from_pdb(input_path+filename), 'score12') for n, filename in enumerate(filenames)]
        p.starmap(pep_run, work)
# Out:
# Overwriting ScreenPeptides.py

# %%
# %run ScreenPeptides.py

# %%
#initialize
fp_dock_init()
# Out:
# PyRosetta-4 2020 [Rosetta PyRosetta4.conda.linux.CentOS.python37.Release 2020.10+release.46415fa3e9decb8b6e91a4e065c15543eb27a461 2020-03-05T09:09:24] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: {0} Checking for fconfig files in pwd and ./rosetta/flags
# core.init: {0} Rosetta version: PyRosetta4.conda.linux.CentOS.python37.Release r248 2020.10+release.46415fa 46415fa3e9decb8b6e91a4e065c15543eb27a461 http://www.pyrosetta.org 2020-03-05T09:09:24
# core.init: {0} command: PyRosetta -pep_refine -ex1 -ex2aro -use_input_sc -ignore_unrecognized_res -database /home/colin/anaconda3/envs/pyrosetta/lib/python3.7/site-packages/pyrosetta/database
# basic.random.init_random_generator: {0} 'RNG device' seed mode, using '/dev/urandom', seed=-1534649857 seed_offset=0 real_seed=-1534649857 thread_index=0
# basic.random.init_random_generator: {0} RandomGenerator:init: Normal mode, seed=-1534649857 RG_type=mt19937

# %%
wt = pose_from_pdb("./native_test.pdb")
mut = Pose()
mut.assign(wt)
toolbox.mutants.mutate_residue(mut, 11, 'A', pack_radius=8)
# Out:
# core.import_pose.import_pose: {0} File './native_test.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CD  on residue GLU 24
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  OE1 on residue GLU 24
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  OE2 on residue GLU 24
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CG  on residue GLN 73
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CD  on residue GLN 73
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  OE1 on residue GLN 73
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  NE2 on residue GLN 73
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CE  on residue LYS 76
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  NZ  on residue LYS 76
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CG  on residue LYS 124
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CD  on residue LYS 124
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  CE  on residue LYS 124
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  NZ  on residue LYS 124
# core.conformation.Conformation: {0} [ WARNING ] missing heavyatom:  OXT on residue ASN:CtermProteinFull 157
# core.pack.pack_missing_sidechains: {0} packing residue number 24 because of missing atom number 7 atom name  CD
# core.pack.pack_missing_sidechains: {0} packing residue number 73 because of missing atom number 6 atom name  CG
# core.pack.pack_missing_sidechains: {0} packing residue number 76 because of missing atom number 8 atom name  CE
# core.pack.pack_missing_sidechains: {0} packing residue number 124 because of missing atom number 6 atom name  CG
# core.pack.task: {0} Packer task: initialize from command line()
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: ref2015
# core.pack.pack_rotamers: {0} built 101 rotamers at 4 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: ref2015
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 195 rotamers at 14 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).

# %%
def pepdock_decoy(pose, reference, position, sf='docking', pack_rad=8):
    sf = create_score_function(sf)
    # Creating FlexPepDock protocol using init options
    fpdock = FlexPepDockingProtocol()
    
    pose_copy = Pose()
    pose_copy.assign(pose)
    reference_copy = Pose()
    reference_copy.assign(reference)

    fpdock.apply(pose_copy)
    
    ddG_val = ddG(reference_copy, pose_copy, position, sf, pack_rad)
    pose_copy.scores['ddG'] = ddG_val
    
    filename = pose_copy.pdb_info().name()
    
    output_scorefile(pose_copy, filename, filename, './decoys', sf, 3, native_pose=reference_copy)

# %%
sf = create_score_function('docking')
output_scorefile(mut, 'test', 'test', './decoys/testscf.json', sf, 3, native_pose=wt)

# %%
pepdock_decoy(mut, wt, 11)
# Out:
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: ref2015
# basic.io.database: {0} Database file opened: scoring/score_functions/EnvPairPotential/env_log.txt
# basic.io.database: {0} Database file opened: scoring/score_functions/EnvPairPotential/cbeta_den.txt
# basic.io.database: {0} Database file opened: scoring/score_functions/EnvPairPotential/pair_log.txt
# basic.io.database: {0} Database file opened: scoring/score_functions/EnvPairPotential/cenpack_log.txt
# core.scoring.ramachandran: {0} shapovalov_lib::shap_rama_smooth_level of 4( aka highest_smooth ) got activated.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/shapovalov/kappa25/all.ramaProb
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/avg_L_rama.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/avg_L_rama.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_all_rama.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_all_rama.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_G_rama.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_G_rama.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_P_rama.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_P_rama.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/avg_L_rama_str.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/avg_L_rama_str.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_all_rama_str.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_all_rama_str.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_G_rama_str.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_G_rama_str.dat.
# basic.io.database: {0} Database file opened: scoring/score_functions/rama/flat/sym_P_rama_str.dat
# core.scoring.ramachandran: {0} Reading custom Ramachandran table from scoring/score_functions/rama/flat/sym_P_rama_str.dat.
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: ref2015
# FlexPepDockingProtocol: {0} apply
# FlexPepDockingProtocol: {0} [ WARNING ] No native supplied by used - using starting structure as reference for statistics
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Receptor chain: A
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Receptor first res: 1
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Receptor nres: 157
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Peptide chain: B
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Peptide first res: 158
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Peptide nres: 13
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Peptide anchor: 164
# protocols.flexPepDocking.FlexPepDockingFlags: {0} # peptide anchors: 1
# protocols.flexPepDocking.FlexPepDockingFlags: {0} # peptide cuts: 0
# protocols.flexPepDocking.FlexPepDockingFlags: {0} Receptor anchor: 151
# FlexPepDockingProtocol: {0} Old FoldTree : FOLD_TREE  EDGE 1 157 -1  EDGE 1 158 1  EDGE 158 170 -1
# FlexPepDockingProtocol: {0} New FoldTree : FOLD_TREE  EDGE 1 151 -1  EDGE 151 157 -1  EDGE 151 164 1  EDGE 164 158 -1  EDGE 164 170 -1
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 902 rotamers at 41 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1376 rotamers at 49 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1466 rotamers at 48 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1383 rotamers at 51 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1254 rotamers at 47 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1082 rotamers at 45 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1100 rotamers at 46 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1095 rotamers at 50 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 969 rotamers at 44 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1028 rotamers at 43 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1053 rotamers at 45 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 973 rotamers at 40 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 953 rotamers at 45 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 1009 rotamers at 47 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 953 rotamers at 44 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 827 rotamers at 42 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 890 rotamers at 42 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 691 rotamers at 47 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 829 rotamers at 41 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 736 rotamers at 44 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 977 rotamers at 43 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.moves.RigidBodyMover: {0} Translate: Jump (before): RT -0.801477 -0.115166 0.586832 -0.286345 -0.787578 -0.545644 0.525015 -0.605358 0.598249 0.80756 4.54037 1.27822
# protocols.moves.RigidBodyMover: {0} Translate: Jump (after):  RT -0.801477 -0.115166 0.586832 -0.286345 -0.787578 -0.545644 0.525015 -0.605358 0.598249 -299.454 -112.946 947.872
# FlexPepDockingPoseMetrics: {0} Isc: -95.4084
# FlexPepDockingPoseMetrics: {0} Total BSA  is: 2140.43
# basic.io.database: {0} Database file opened: scoring/score_functions/hbonds/sp2_elec_params/HBPoly1D.csv
# basic.io.database: {0} Database file opened: scoring/score_functions/hbonds/sp2_elec_params/HBFadeIntervals.csv
# basic.io.database: {0} Database file opened: scoring/score_functions/hbonds/sp2_elec_params/HBEval.csv
# FlexPepDockingPoseMetrics: {0} Interface HB #: 21
# FlexPepDockingPoseMetrics: {0} Total packstats: -0.0298579
# FlexPepDockingPoseMetrics: {0} Interface Unsat polar groups: 6
# FlexPepDockingPoseMetrics: {0} 158 bsa: 32.5284 HB: 1 pack: 0.305939 unsat: 0
# FlexPepDockingPoseMetrics: {0} 159 bsa: 119.561 HB: 2 pack: 0.492648 unsat: 0
# FlexPepDockingPoseMetrics: {0} 160 bsa: 86.3215 HB: 2 pack: 0.705262 unsat: 0
# FlexPepDockingPoseMetrics: {0} 161 bsa: 56.5404 HB: 2 pack: 0.349153 unsat: 0
# FlexPepDockingPoseMetrics: {0} 162 bsa: 136.367 HB: 2 pack: 0.706849 unsat: 0
# FlexPepDockingPoseMetrics: {0} 163 bsa: 190.266 HB: 2 pack: 0.225642 unsat: 0
# FlexPepDockingPoseMetrics: {0} 164 bsa: 114.173 HB: 4 pack: 0.570599 unsat: 0
# FlexPepDockingPoseMetrics: {0} 165 bsa: 96.3504 HB: 2 pack: 0.438713 unsat: 0
# FlexPepDockingPoseMetrics: {0} 166 bsa: 57.5568 HB: 2 pack: 0.469946 unsat: 0
# FlexPepDockingPoseMetrics: {0} 167 bsa: 149.299 HB: 0 pack: 0.774803 unsat: 0
# FlexPepDockingPoseMetrics: {0} 168 bsa: 58.6701 HB: 2 pack: 0.500598 unsat: 0
# FlexPepDockingPoseMetrics: {0} 169 bsa: 19.2164 HB: 0 pack: 0.127208 unsat: 0
# FlexPepDockingPoseMetrics: {0} 170 bsa: 0 HB: 0 pack: 0.204473 unsat: 0
# protocols.evaluation.ChiWellRmsdEvaluatorCreator: {0} Evaluation Creator active ...
# FlexPepDockingProtocol: {0}  residue 5 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 7 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 9 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 10 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 11 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 12 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 13 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 14 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 15 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 16 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 17 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 18 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 20 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 21 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 24 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 40 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 144 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 147 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 148 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 149 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 150 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 151 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 152 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 153 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 154 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 155 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 156 A  is at the interface
# FlexPepDockingProtocol: {0}  residue 157 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 158 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 159 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 160 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 161 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 162 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 163 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 164 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 165 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 166 B  is at the interface
# FlexPepDockingProtocol: {0}  residue 167 B  is at the interface
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-a6faa2206697> in <module>
# ----> 1 pepdock_decoy(mut, wt, 11)
#
# <ipython-input-62-5686ec353851> in pepdock_decoy(pose, reference, position, sf, pack_rad)
#      11     fpdock.apply(pose_copy)
#      12
# ---> 13     ddG_val = ddG(reference_copy, pose_copy, position, sf, pack_rad)
#      14     pose_copy.scores['ddG'] = ddG_val
#      15
#
# ~/code/ScreenPeptides/ScreenPeptides.py in ddG(wt_pose, mut_pose, mutant_position, sf, repack_distance, replicate_runs)
#     124     for _ in range(replicate_runs):
#     125         wt_score = calc_binding_energy(wt_pose, sf,
# --> 126             mutant_position, repack_distance)
#     127         mut_score = calc_binding_energy(mut_pose, sf,
#     128             mutant_position, repack_distance)
#
# ~/code/ScreenPeptides/ScreenPeptides.py in calc_binding_energy(pose, scorefxn, center, cutoff)
#      19 # copied from D090_Ala_scan.py in the example scripts for PyRosetta
#      20 def calc_binding_energy(pose, scorefxn, center, cutoff = 8.0):
# ---> 21     scorefxn = create_score_function(scorefxn)
#      22
#      23     # create a copy of the pose for manipulation
#
# TypeError: create_score_function(): incompatible function arguments. The following argument types are supported:
#     1. (weights_tag: str) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#     2. (options: pyrosetta.rosetta.utility.options.OptionCollection, weights_tag: str) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#     3. (weights_tag: str, patch_tag: str) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#     4. (options: pyrosetta.rosetta.utility.options.OptionCollection, weights_tag: str, patch_tag: str) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#     5. (weights_tag: str, patch_tags: pyrosetta.rosetta.utility.vector1_std_string) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#     6. (options: pyrosetta.rosetta.utility.options.OptionCollection, weights_tag: str, patch_tags: pyrosetta.rosetta.utility.vector1_std_string) -> pyrosetta.rosetta.core.scoring.ScoreFunction
#
# Invoked with: <pyrosetta.rosetta.core.scoring.ScoreFunction object at 0x7fd8766341b0>
